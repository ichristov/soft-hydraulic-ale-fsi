# %% [markdown]
# # Preliminaries

# %% [markdown]
# <span style="color: red"><b>WARNING:</span> this notebook has been tested on fenics-dolfin 2019.1.0 (classic); at some point it may be all deprecated.</b>

# %%
from dolfin import *
from ufl import indices, Jacobian, Min, Max, And, shape

import numpy as np
# handle numpy 1.x and 2.x
try:
    from numpy import trapezoid as trapz
except ImportError:
    from numpy import trapz  # NumPy < 2.0
    
import os, pygmsh, gmsh, meshio

# %%
# plotting customizations
from matplotlib import pyplot as plt
from matplotlib import tri, colormaps, colors, cm
from mpl_toolkits.mplot3d import axes3d
size=18
params = {'legend.fontsize': size*0.75,
        #   'figure.figsize': (20,8),
          'text.usetex': True,
          'text.latex.preamble': r'\usepackage{mathrsfs,bm}',
        #   'mathtext.fontset': 'stix',
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.875,
          'ytick.labelsize': size*0.875,
          'axes.titlepad': 25,
          'animation.embed_limit': 2**128}
plt.rcParams.update(params)
# %matplotlib inline

# %% [markdown]
# ## Credit
#
# Based heavily on [fitted-fsi-example](https://github.com/david-kamensky/mae-207-fea-for-coupled-problems/tree/master/fsi) from David Kamensky's [MAE 207: FEA for coupled problems](https://github.com/david-kamensky/mae-207-fea-for-coupled-problems/tree/master) course at UC San Diego.
#
# [Initial version](https://github.com/Radeu/Radeu-FSI-in-2D-Deformable-Channel-with-Oscillatory-Pressure-BC) written by U. Rade, Purdue University, for the simulations in the paper "Theory and simulation of elastoinertial rectification of oscillatory flows in two-dimensional deformable rectangular channels" (preprint [arXiv:2505.22799](https://arxiv.org/abs/2505.22799); PURR dataset [doi:10.4231/50C7-HK87](https://dx.doi.org/10.4231/50C7-HK87)).
#
# Next rewrite by [Ivan C. Christov](http://christov.tmnt-lab.org), Purdue University (with input from Copilot) includes:
# - converting to notebook format for easier on-the-fly analysis,
# - complete reorganization of simulation and model parameter initialization,
# - switching to gmsh for modern meshing,
# - implementing Carreau viscosity model for fluid,
# - implementing 2D restriction of neo-Hookean solid,
# - implementing velocity-based damping in the solid for improved convergence to steady state,
# - adding steady analytical solution comparisons,
# - post-processing, benchmarks, and Matplotlib visualizations,
# - various other small improvements.

# %% [markdown]
# If you want to run this solver as a standalone python script (stripping all Markdown comments, etc), run the following command in your terminal:
#
# `
# jupyter nbconvert new_ALE-FSI_2D.ipynb --to python --PythonExporter.exclude_markdown=True
# `
#
# which creates the file `new_ALE-FSI_2D.py`.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Sketch of the geometry and notation.
#
# ![oscillatory flow in a deformable channel](data:image/png;base64,...)

# %% [markdown]
# <span style="color: red">WARNING:</span> Carreau model is only implemented in the numerics. The theory relies on the power-law approximation &amp; Winkler-foundation elastic model.

# %% [markdown]
# # Problem setup

# %% [markdown]
# ## General simulation settings

# %% [markdown]
# ### Data storage

# %%
# If the folder does not exist, create it.
# I'm using a folder that will not get synced to GitHub.
DataFolder = "not-ready-for-github/simulation_output/"
if not os.path.exists(DataFolder):
    os.makedirs(DataFolder)
    print(f"CREATED data storage folder: {DataFolder}")
else:
    print(f"Using EXISTING data storage folder: {DataFolder}")
# Out:
# Using EXISTING data storage folder: not-ready-for-github/simulation_output/

# %% [markdown]
# ### Algorithmic settings
#
# Shouldn't require changing.

# %%
LSIC            = False     # Least-squares incompressibility stabilization for fluid
BACKFLOW_STAB   = True      # Backflow stabilization for fluid
SUPG            = False     # Streamline Upwind Petrov-Galerkin stabilization for fluid
                            # shouldn't needed for low Re flow or with Taylor-Hood elements

print("============================ INFO ============================")
print(f"SUPG stabilization:       {'ON' if SUPG else 'OFF'}")
print(f"LSIC stabilization:       {'ON' if LSIC else 'OFF'}")
print(f"Backflow stabilization:   {'ON' if BACKFLOW_STAB else 'OFF'}")
print("=============================================================")
# Out:
# ============================ INFO ============================
# SUPG stabilization:       OFF
# LSIC stabilization:       OFF
# Backflow stabilization:   ON
# =============================================================

# %% [markdown]
# ## General problem settings

# %% [markdown]
# ### Parameters defining domain geometry

# %%
b0 = 0.01
h0 = b0
l  = 50*h0
# Solid domain extents:
SOLID_TOP    = h0+b0
SOLID_BOTTOM = h0
SOLID_LEFT   = 0.0
SOLID_RIGHT  = l
# Combined domain size:
OMEGA_H      = h0+b0
OMEGA_W      = l
# Flags for subdomains:
FLUID_FLAG   = 0
SOLID_FLAG   = 1
# Desired resolution of mesh:
N = 100 # 600
# Refine near inlet in SOLID domain only
inlet_refinement_solid_only = True
inlet_refinement = 0.33 # 1 = no refinement, 1/() times finer
# Refinement near fluid-solid interface
interface_refinement = 0.33 # 1 = no refinement, 1/() times finer
# Geometry-scale tolerance for subdomains:
d_tol = h0 * 1e-8

# %% [markdown]
# ### Material properties (dimensional)

# %% [markdown]
# The solid is linearly elastic (with material constants $E_s$, $\nu_s$).
#
# The fluid is a generalized Newtonian fluid with shear-thinning behavior described by the Carreau model:
# \begin{align*}
#      \eta(\dot{\gamma})
#      &= \eta_{\infty} + \left(\eta_0-\eta_{\infty}\right) \left[ 1 + (\lambda \dot{\gamma})^2 \right]^{(n-1)/2} \\
#      &= \eta_{0} \left\{ \beta + (1-\beta) \left[ 1 + (\lambda \dot{\gamma})^2 \right]^{(n-1)/2} \right\} \\
#      &= \eta_{0} \left\{ \beta + (1-\beta) |\lambda \dot{\gamma}|^{n-1} \right\}, \qquad |\lambda \dot{\gamma}| \gg 1 \\
#      &= \eta_{0} |\lambda \dot{\gamma}|^{n-1}\qquad\qquad\;\;\; \beta \ll 1,\quad |\lambda \dot{\gamma}| \gg 1.
# \end{align*}

# %%
# Elasticity model for real solid:
ELASTICITY_MODEL = "NEOH"  # "STVK" for Saint-Venant--Kirchhoff 
                           # "NEOH" for neo-Hookean, more robust than STVK

# Elastic solid's properties:
E_s    = 5e+5                           # Young's modulus
nu_s   = 0.45                           # Poisson ratio
mu_s   = Constant(E_s/(2*(1+nu_s)))     # Shear modulus
K      = Constant(E_s/(3*(1-2*nu_s)))   # Bulk modulus
rho_s0 = Constant(1e3)                  # Solid's density if ref. config.
cs     = sqrt(mu_s/rho_s0)              # Shear wave speed in solid
#print("Shear wave speed in solid is", f"{float(cs):.4g}")   # .4g = 4 sig figs
zeta   = 0.10
cd_est = 2.0 * zeta * float(cs / b0)
print(f"Try damping coeff ~ {cd_est:.3g} 1/s for damping factor = {zeta:.3g}")
cd     = Constant(1.0*cd_est)           # Velocity-based damping coefficient 
                                        # (to suppresses transients for steady simulations)

# Viscous fluid properties to yield desired dimensionless numbers,
# based on dynamic similarity:
rho_f     = Constant(1e1)               # Fluid's density
eta_f_0   = Constant(10.0)              # Zero-shear viscosity ~ 0.1
eta_f_inf = Constant(0.0)               # Inf-shear viscosity, ~0.01 or 0.0001
n         = Constant(1.0)               # Shear-thinning/plaw index, ~0.5
lam_r     = Constant(0.0)               # Char. shear rate for thinning, ~10.0
# Consistency index for power-law approximation:
m_plaw    = eta_f_0*lam_r**(n-1)
# Out:
# Try damping coeff ~ 263 1/s for damping factor = 0.1

# %% [markdown]
# ### Dimensionless numbers

# %% [markdown]
# To determine the scales and dimensionless numbers we need to pick the BC type here.

# %%
FLOW_OR_PRESSURE = "PRESSURE"    # "FLOW" or "PRESSURE"

p_amp = Constant(2e5)            # Pressure amplitude
q_amp = Constant(0.1)            # Flow rate amplitude

# %%
# Adjust scales for either flow rate or pressure control BC:
if FLOW_OR_PRESSURE == "FLOW":
    q_c = q_amp
    v_c = q_c/h0
    p_c = m_plaw*l*(q_c**n)/h0**(2*n+1)  #eta_f_0*q_c*l/h0**3
    dp_rigid = (2**(1+1/n)*(2+1/n))*float(p_c)
    q_rigid = float(q_c)
elif FLOW_OR_PRESSURE == "PRESSURE":
    p_c = p_amp
    q_c = ((p_c/l)*(h0**(2*n+1)/m_plaw))**(1/n) #(p_c/l)*(h0**3/eta_f_0)
    v_c = q_c/h0
    dp_rigid = float(p_c)
    q_rigid = float(q_c/(2**(1+1/n)*(2+1/n)))
else:
    raise ValueError("FLOW_OR_PRESSURE must be either 'FLOW' or 'PRESSURE'")

# %%
omega = 0                                                    # Frequency (for oscillatory flow)

epsilon_f = h0/l                                             # Fluid (inverse) aspect ratio
epsilon_s = b0/l                                             # Solid (inverse) aspect ratio

C_I = 2*nu_s*(nu_s-1/4)/(3*(1-nu_s)**2)*(b0**3/mu_s/l**2)    # Incompressible foundation compliance
C_w = (1-2*nu_s)/(2*(1-nu_s))*(b0/mu_s)                      # Winkler foundation compliance
C_H = (nu_s-1/4)/(1-nu_s)*(b0**2/mu_s/l)                     # Horizontal component compliance
theta = float(C_I/C_w)
vartheta = float(C_H/C_w)
alpha = float(p_c/(h0/C_w))                                  # Compliance number

Wo = sqrt(h0**2 * omega/float(eta_f_0/rho_f))                # Womersley number

gamma = float(C_w*l*eta_f_0*omega/(epsilon_f*h0**2))         # Elastoviscous number

#Re = float(rho_f * epsilon_f**2 * h0**2 * p_c/eta_f**2)     # Reynolds number
Re = float(epsilon_f * rho_f * v_c * h0/eta_f_0) 
#Re = float(Wo**2 * alpha/gamma)                             # Only if unsteady

beta = float(eta_f_inf/eta_f_0)                              # Carreau viscosity ratio
Cu = float(lam_r * v_c/h0)                                   # Carreau number

print("============================ INFO ===========================")
print(f">>> Using {FLOW_OR_PRESSURE}-controlled BC & appropriate scales.")
print("-------------------------------------------------------------")
print(f"ε_f = {epsilon_f:.5f}")
print(f"ε_s = {epsilon_s:.5f}")
print(f"θ   = {theta:.5f}")
print(f"α   = {alpha:.5f} (compliance #)")
print(f"Wo  = {Wo:.5f} (Womersley #)")
print(f"γ   = {gamma:.5f} (Elastoviscous #)")
print(f"εRe = {Re:.5f} (Reynolds #)")
print(f"β   = {beta:.5f} (viscosity ratio)")
print(f"Cu  = {Cu:.5f} (Carreau #)")
print("=============================================================")
# Out:
# ============================ INFO ===========================
# >>> Using PRESSURE-controlled BC & appropriate scales.
# -------------------------------------------------------------
# ε_f = 0.02000
# ε_s = 0.02000
# θ   = 0.00087
# α   = 0.10545 (compliance #)
# Wo  = 0.00000 (Womersley #)
# γ   = 0.00000 (Elastoviscous #)
# εRe = 0.00080 (Reynolds #)
# β   = 0.00000 (viscosity ratio)
# Cu  = 0.00000 (Carreau #)
# =============================================================

# %% [markdown]
# ### Analytical solutions: for comparisons, etc

# %% [markdown]
# #### Rigid channel

# %% [markdown]
# Currently, implementing only the steady power-law 2D channel flow solution.
#
# **TODO:** Implement oscillatory (Womersley) 2D channel flow solution for Newtonian case.

# %%
# Note that "x" in v_in and/or p_in is really "y" in the kinematics described below,
# but, because the mesh motion problem has a zero Dirichlet BC on the inflow boundary, 
# there happens to be no difference between "x" and "y".

# x[1] < h0 is needed if we want to evaluate this 
# over the whole Omega domain as an initial condition
p_rigid = Expression("x[1] < h0 + eps ? (dp/L)*(L-x[0]) : 0.0",
                     dp=float(p_amp), h0=float(h0), L=float(l), eps=d_tol, degree=1)

v_rigid = Expression(
    ("x[1] < h0 + eps ? "
     "q0/h0*(2+1/n)*(1/(1+1/n))*(1-pow(abs(1-2*x[1]/h0), 1+1/n)) : 0.0",
     "0.0"),
    q0=float(q_amp), h0=float(h0), n=float(n), eps=d_tol, degree=2
)

p_rigid.dp = float(dp_rigid)
v_rigid.q0 = float(q_rigid)

# %% [markdown]
# #### Compliant channel

# %% [markdown]
# Implementing Eq. (41) and related results from "[Soft hydraulics: from Newtonian to complex fluid flows through compliant conduits](https://dx.doi.org/10.1088/1361-648X/ac327d)" (preprint [arXiv:2106.07164](https://arxiv.org/abs/2106.07164)):
# $$
#     %-\frac{dp}{d{z}} = \frac{2^{1+n}(2+1/n)^n m q^n}{[h_0 + \mathcal{C} p(z)]^{1+2n}w^n},
#     -\frac{dp}{d{z}} = \frac{2^{1+n}(2+1/n)^n m q^n}{[h_0 + \mathcal{C} p(z)]^{1+2n}},\quad p(\ell) = 0,
# $$
# which can be integrated directly when $q$ is given (flow-rate control), or differentiated once and solved as
# $$
#     \frac{d}{d{z}}\left\{ [h_0 + \mathcal{C} p(z)]^{1+2n} \frac{dp}{d{z}}  \right\} = 0,\quad p(0) = \Delta p,\quad p(\ell) = 0,
# $$
# when $\Delta p$ is given (pressure-drop control).

# %%
nhat_factor = 2**(1 + n) * (2 + 1/n)**n
if FLOW_OR_PRESSURE == "FLOW":
    p_sh = Expression("pc/a*(pow(1 + nhat*a*(1.0-x[0]/L), 1/(2+2*n)) - 1.0)",
                      pc=float(p_c), a=float(alpha), L=float(l), 
                      n=float(n), nhat=float(nhat_factor*(2+2*n)), degree=1)
    q_sh = q_sh_in = q_sh_out = q_rigid
elif FLOW_OR_PRESSURE == "PRESSURE":
    p_sh = Expression("pc/a*(pow(pow(1+a, 2+2*n)*(1-x[0]/L)+x[0]/L, 1/(2+2*n)) - 1.0)",
                      pc=float(p_c), a=float(alpha), L=float(l), n=float(n), degree=4)
    # pressure gradient at z = 0 from dp_sh/dz|_{z=0}
    dp_shdz0 = (p_c / (alpha * l * (2 + 2*n))) * ((1 + alpha)**(-(1 + 2*n)) - (1 + alpha))
    # q = const; channel half-height at inlet = h0*(1+alpha) since p_sh(0) = p_c
    q_sh = q_sh_in = q_sh_out = ((-dp_shdz0) * (h0*(1+alpha))**(1+2*n) / m_plaw / nhat_factor)**(1/n)
else:
    raise ValueError("FLOW_OR_PRESSURE must be either 'FLOW' or 'PRESSURE'")

# %% [markdown]
# ## Derived simulation settings

# %% [markdown]
# ### Domain and mesh

# %% [markdown]
# Gmsh-based geometry & mesh.

# %%
# Generate custom mesh generation with local refinements:
from build_mesh_with_gmsh import build_mesh_with_gmsh

xdmf_path = build_mesh_with_gmsh(N,
                                 [0.0, OMEGA_W, 0.0, OMEGA_H, SOLID_BOTTOM],
                                 DataFolder+"fsi_rect",
                                 inlet_refinement=inlet_refinement, 
                                 inlet_refinement_solid_only=inlet_refinement_solid_only,
                                 interface_refinement=interface_refinement)

# Without any refinement (behaves like original code)
# xdmf_path = build_mesh_with_gmsh(h)

# Load back into dolfin from XDMF:
mesh = Mesh()
with XDMFFile(xdmf_path) as f:
    f.read(mesh)

# Mesh-derived quantities:
d   = mesh.geometry().dim()
n_y = FacetNormal(mesh)
I   = Identity(d)
# Out:
# Info    : Found interface curve 4: x = [-0.000000, 0.500000], y = 0.010000
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 50%] Meshing curve 4 (Line)
# Info    : [ 60%] Meshing curve 5 (Line)
# Info    : [ 80%] Meshing curve 6 (Line)
# Info    : [ 90%] Meshing curve 7 (Line)
# Info    : Done meshing 1D (Wall 0.293135s, CPU 0.236078s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0697903s, CPU 0.083597s)
# Info    : 1267 nodes 2783 elements
# Info    : Writing 'not-ready-for-github/simulation_output/fsi_rect.msh'...
# Info    : Done writing 'not-ready-for-github/simulation_output/fsi_rect.msh'

# %%
# Visualize the mesh real quick:
plot(mesh)
plt.gca().lines[0].set_linewidth(0.5)
plt.gca().set_aspect(2.5/1)
plt.gca().set_xlim(0, l)
plt.gca().set_xlabel("$z$")
plt.gca().set_ylabel("$y$")
plt.gca().set_ylim(0, h0+b0)
plt.gcf().set_size_inches(12, 6)
plt.plot(np.linspace(0, l, 10), np.ones(10)*(h0+b0)/2,
         linestyle='--', linewidth=1.0, color='red')
plt.show()

# %%
# Define subdomains for use in boundary condition definitions:
class Wall_b(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[1] < d_tol))

class Wall_t(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[1] > SOLID_TOP - d_tol))

class Wall_l(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[0] < d_tol)
                and x[1] > SOLID_BOTTOM - d_tol)

class Wall_r(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[0] > SOLID_RIGHT - d_tol)
                and x[1] > SOLID_BOTTOM - d_tol)

class Inflow(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[0] < d_tol)
                and x[1] < SOLID_BOTTOM + d_tol)

class Outflow(SubDomain):
    def inside(self, x, on_boundary):
        return (on_boundary and (x[0] > (OMEGA_W - d_tol))
                and x[1] < SOLID_BOTTOM + d_tol)

class SolidDomainClosure(SubDomain):
    def inside(self, x, on_boundary):
        return (x[1] > SOLID_BOTTOM - d_tol
                and x[1] < SOLID_TOP + d_tol
                and x[0] > SOLID_LEFT - d_tol
                and x[0] < SOLID_RIGHT + d_tol)

class SolidDomainInterior(SubDomain):
    def inside(self, x, on_boundary):
        return (x[0] > SOLID_LEFT - d_tol
                and x[0] < SOLID_RIGHT + d_tol
                and x[1] < SOLID_TOP + d_tol
                and x[1] > SOLID_BOTTOM + d_tol)

# %%
# Markers instead of mshr.domains():
markers = MeshFunction('size_t', mesh, d)
markers.set_all(FLUID_FLAG)                      # default: fluid = 0
SolidDomainClosure().mark(markers, SOLID_FLAG)   # reset: solid = 1

# Facet markers (0 = default):
facet_tags = MeshFunction('size_t', mesh, d-1, 0)

# Mark boundaries with IDs, if you wish:
# BOTTOM, LEFT, RIGHT, TOP = 11, 12, 13, 14
# Wall_b().mark(facet_tags, BOTTOM)
# Wall_l().mark(facet_tags, LEFT)
# Wall_r().mark(facet_tags, RIGHT)
# Wall_t().mark(facet_tags, TOP)
INFLOW, OUTFLOW = 3, 2 
Inflow().mark(facet_tags, INFLOW)
Outflow().mark(facet_tags, OUTFLOW)

# Quadrature-aware exterior measure with facet markers:
dx = dx(metadata={'quadrature_degree': 2}, subdomain_data=markers)
ds = ds(metadata={'quadrature_degree': 2}, subdomain_data=facet_tags)

# %% [markdown]
# ### Time stepping details

# %% [markdown]
# Time stepping details come after setting the everything else, so that we can properly set them for the _given_ problem.

# %%
# Fixed physical time step [s] to achieve a given CFL.
CFL            = 10.0
Dt             = Constant(CFL*mesh.hmin()/float(v_c))
# Need to tune this to ensure the ramp is gradual enough;
# if there are too many (dozens) of coupling iters, reduce it.
MAX_DELTA_H    = 2e-3
# Target pressure increment per time step [Pa/step]:
P_RAMP_RATE    = MAX_DELTA_H * float(p_c) / alpha
# No. time steps needed to ramp from 0 to p_sh(0)
N_T_STEPS_RAMP = int(np.ceil(float(p_sh(0)) / P_RAMP_RATE))
# No. time steps to hold at final pressure after ramping:
N_T_STEPS      = 2*N_T_STEPS_RAMP 
# Thus:
RAMP_TIME      = N_T_STEPS_RAMP*float(Dt)
FINAL_TIME     = N_T_STEPS*float(Dt)
N_SKIP         = 5

print(f"p_sh(0) = {float(p_sh(0)):.3g} Pa")
print(f"Target pressure increment per time step: {float(P_RAMP_RATE):.3g} Pa/step")
print(f"Number of time steps: {N_T_STEPS}, Δt: {float(Dt):.3g} s")
print(f"Ramp time: {RAMP_TIME:.3g} s, Final time: {FINAL_TIME:.3g} s")
# Out:
# p_sh(0) = 2e+05 Pa
# Target pressure increment per time step: 3.79e+03 Pa/step
# Number of time steps: 106, Δt: 0.00356 s
# Ramp time: 0.189 s, Final time: 0.378 s

# %% [markdown]
# ### Boundary conditions

# %% [markdown]
# Implementation of the boundary conditions come after setting the everything else, so that we can properly set them for the _given_ problem.

# %%
if np.isclose(omega, 0):
    # Ramped-up-to-steady BC:
    p_in  = Expression("p0*(t<tr ? t/tr : 1.0)", 
                       p0=float(p_amp), tr=float(RAMP_TIME), t=0.0, degree=1)
    # Newtonian parabolic profile with ramped-up flow rate:
    # v_in  = Expression(("x[1] < h0 + eps ? 6*(q0*(t<tr ? t/tr : 1.0)/h0)*(x[1]/h0)*(h0-x[1])/h0 : 0.0", "0.0"), 
    #                    tr=float(RAMP_TIME), q0=float(q_amp), h0=float(h0), t=0.0, degree=2)
    # Power-law profile with ramped-up flow rate:
    v_in = Expression(
        ("x[1] < h0 + eps ? "
        "q0*(t<tr ? t/tr : 1.0)/h0 * (2+1/n)/(1+1/n)"
        "*(1 - pow(abs(2*x[1]/h0 - 1),1+1/n)) : 0.0", "0.0"),
        q0=float(q_amp), 
        h0=float(h0),
        n=float(n),
        eps=d_tol, 
        tr=float(RAMP_TIME),
        t=0.0,
        degree=2
    )
else:
    # Oscillatory flow BCs:
    print(f"Oscillation period: {2*np.pi/omega:.3g} s")
    p_in  = Expression("p0*cos(w*t)", 
                       p0=float(p_amp), w=float(omega), t=0.0, degree=1)
    # Newtonian parabolic profile with oscillating flow rate:
    # v_in  = Expression(("x[1] < h0 + eps ? 6*(q0/h0)*cos(w*t)*(x[1]/h0)*(h0-x[1])/h0 : 0.0", "0.0"), 
    #                    q0=float(q_amp), w=float(omega), h0=float(h0), t=0.0, degree=2)
    # Power-law profile with oscillating flow rate:
    v_in = Expression(
        ("x[1] < h0 + eps ? "
        "q0*cos(w*t)/h0 * (2+1/n)/(1+1/n)"
        "*(1 - pow(abs(2*x[1]/h0 - 1),1+1/n)) : 0.0", "0.0"),
        q0=float(q_amp), 
        h0=float(h0),
        n=float(n),
        eps=d_tol,
        w=float(omega),
        t=0.0,
        degree=2
    )

# %% [markdown]
# # Variational problem definitions

# %% [markdown]
# ## Elements and function spaces

# %%
# Define function spaces (equal order interpolation):
cell = mesh.ufl_cell()
Ve = VectorElement("CG", cell, 2) # can also be 1 since we have stabilization
Qe = FiniteElement("CG", cell, 1)
VQe = MixedElement((Ve,Qe))

# Mixed function space for velocity and pressure:
W = FunctionSpace(mesh, VQe)

# Function space for mesh displacement field, 
# which will be solved for separately in a 
# quasi-direct scheme:
Vm = VectorElement("CG", cell, 1)
V = FunctionSpace(mesh,Vm)

# %% [markdown]
# ## Time integration variables

# %%
# Mesh motion functions:
uhat = Function(V)
uhat_old = Function(V)
du = TestFunction(V)
vhat = (uhat-uhat_old)/Dt

# Fluid--structure functions:
(dv, dp) = TestFunctions(W)
w = Function(W)
v, p = split(w)
p_mean = Function(W)
w_old = Function(W)
v_old, p_old = split(w_old)
dv_dr = (v - v_old)/Dt
dv_ds = dv_dr # (Only valid in solid)

# This is the displacement field used in the 
# solid formulation; notice that it is NOT 
# in the space V; it is an algebraic object 
# involving the unknown fluid--structure velocity 
# field v.
u = uhat_old + Dt*v

# This will need to be updated to match u, for 
# purposes of setting the boundary condition 
# on the mesh motion subproblem.
u_func = Function(V)

# %% [markdown]
# ## ALE kinematics (change of variables)

# %%
# Follow notation from Bazilevs et al., where y is 
# the coordinate in the reference domain, x is the 
# coordinate in the spatial domain, and X is the 
# coordinate in the material domain.  Note that 
# the built-in differential operators (e.g., grad, 
# div, etc.) and integration measures (e.g., dx, ds, 
# etc.) are w.r.t. the reference configuration, y, 
# which is the mesh that FEniCS sees.  
dX = dx(SOLID_FLAG)
dy = dx
ds_y = ds

grad_y = grad
grad_X = grad # (Only valid in solid)

y = SpatialCoordinate(mesh)
x = y + uhat

det_dxdy = det(grad_y(x))

def grad_x(f):
    return dot(grad_y(f),inv(grad_y(x)))

def div_x(f): # (For vector-valued f)
    return tr(grad_x(f))

def div_x_tens(f): # (For (rank-2) tensor-valued f)
    i,j = indices(2)
    return as_tensor(grad_x(f)[i,j,j],(i,))

# Note:  Trying to define dx = det_dxdy*dy would 
# result in an object of type Form, which could no 
# longer be used as an integration measure.
# Thus, integration over the spatial configuration 
# is done with det_dxdy*dy directly in the fluid 
# formulation.

# %% [markdown]
# ## Boundary conditions (simulation)

# %%
# BCs for the fluid--structure subproblem:
bc_b_fs = DirichletBC(W.sub(0), Constant(d*(0.0,)), Wall_b())
bc_l_fs = DirichletBC(W.sub(0), Constant(d*(0.0,)), Wall_l())
bc_r_fs = DirichletBC(W.sub(0), Constant(d*(0.0,)), Wall_r())
bc_t_fs = DirichletBC(W.sub(0), Constant(d*(0.0,)), Wall_t())

# Inlet BC: either flow rate or pressure
if FLOW_OR_PRESSURE == "FLOW":
    bc1_fs = DirichletBC(W.sub(0), v_in, Inflow())
elif FLOW_OR_PRESSURE == "PRESSURE":
    bc1_fs = DirichletBC(W.sub(1), p_in, Inflow())
else:
    raise ValueError("FLOW_OR_PRESSURE must be either 'FLOW' or 'PRESSURE'")

bc2_fs = DirichletBC(W.sub(1), Constant(0.0), SolidDomainInterior())                     

bcs_fs = [bc_b_fs, bc_l_fs, bc_r_fs, bc_t_fs, bc1_fs, bc2_fs]
#bcs_fs = [bc_b_fs, bc1_fs, bc2_fs]

# BCs for the mesh motion subproblem:
#bc_m_wall_b  = DirichletBC(V.sub(1), Constant(0.0), Wall_b())
#bc_m_wall_t  = DirichletBC(V.sub(1), Constant(0.0), Wall_t())
bc_m_wall_b  = DirichletBC(V, Constant(d*(0.0,)), Wall_b())
bc_m_wall_t  = DirichletBC(V, Constant(d*(0.0,)), Wall_t())
# Roller BCs on left & right walls of solid & fluid domain:
# bc_m_wall_l  = DirichletBC(V.sub(0), Constant(0.0), Wall_l())
# bc_m_wall_r  = DirichletBC(V.sub(0), Constant(0.0), Wall_r())
# bc_m_inflow  = DirichletBC(V.sub(0), Constant(0.0), Inflow())
# bc_m_outflow = DirichletBC(V.sub(0), Constant(0.0), Outflow())
# "Full" Dirichlet BCs on left & right walls of solid & fluid domain:
bc_m_wall_l  = DirichletBC(V, Constant(d*(0.0,)), Wall_l())
bc_m_wall_r  = DirichletBC(V, Constant(d*(0.0,)), Wall_r())
bc_m_inflow  = DirichletBC(V, Constant(d*(0.0,)), Inflow())
bc_m_outflow = DirichletBC(V, Constant(d*(0.0,)), Outflow())

bc_m_struct  = DirichletBC(V, u_func, SolidDomainClosure())

bcs_m        = [bc_m_struct, 
                bc_m_wall_b, bc_m_wall_l, bc_m_wall_r, bc_m_wall_t, 
                bc_m_inflow, bc_m_outflow]

# %% [markdown]
# ## Mesh motion subproblem

# %%
# Residual for mesh, which satisfies a fictitious elastic problem:
F_m = grad_y(uhat) + I
E_m = 0.5*(F_m.T*F_m - I)
m_jac_stiff_pow = Constant(3.0)

# Artificially stiffen the mesh where it is getting crushed:
K_m    = Constant(1.0)/pow(det(F_m),m_jac_stiff_pow)
mu_m   = Constant(1.0)/pow(det(F_m),m_jac_stiff_pow)
S_m    = K_m*tr(E_m)*I + 2.0*mu_m*(E_m - tr(E_m)*I/3.0)
res_m  = (inner(F_m*S_m,grad_y(du)))*dy
Dres_m = derivative(res_m, uhat)

# %% [markdown]
# ## Solid subproblem

# %%
# Kinematics:
F = grad_X(u) + I

if ELASTICITY_MODEL == "STVK":
    E = 0.5*(F.T*F - I)
    S_solid = K*tr(E)*I + 2.0*mu_s*(E - tr(E)*I/3.0)
elif ELASTICITY_MODEL == "NEOH":
# Isochoric-volumetric Neo-Hookean (preferred for nu close to 0.5)
    J_s = det(F)
    C = F.T * F
    # Plane strain: F_{33}=1 -> C_{33}=1 -> I1_3D = tr(C_{2D}) + 1
    # WARNING: this +1 is wrong for plane stress or axisymmetry!
    I1 = tr(C) + Constant(1.0)
    Cinv = inv(C)
    
    # Isochoric part is always the same:
    S_iso = mu_s * J_s**Constant(-2.0/3.0) * (I - Constant(1.0/3.0)*I1*Cinv)
    
    # Volumetric stress S_vol = J * p * Cinv, where p = dU/dJ
    # Several common choices for U(J) -- all equivalent near J=1:
    # 1. Quadratic (simplest; does not blow up as J->0):
    #    U = (K/2)*(J-1)^2,  p = K*(J-1)
    S_vol = K * (J_s - Constant(1.0)) * J_s * Cinv
    
    # 2. Simo & Hughes (1998) / Bazilevs et al. (2013)
    #    U = (K/4)*(J^2-1) - (K/2)*ln(J),  p = (K/2)*(J - 1/J)
    #    Satisfies p -> -inf as J->0 (impenetrability). Recommended for large deformations.
    # S_vol = Constant(0.5) * K * (J_s**2 - Constant(1.0)) * Cinv

    # 3. Log-squared / standard compressible neo-Hookean
    #    U = (lam_s/2)*(ln J)^2,  p = lam_s*ln(J)/J
    #    Paired with S_iso when NOT using isochoric split (lam_s not K).
    # S_vol = (K - 2*mu_s/3) * ln(J_s) * Cinv
    
    # 2nd Piola-Kirchhoff stress:
    S_solid = S_iso + S_vol
else:
    raise ValueError("Unknown value of ELASTICITY_MODEL!")

# 1st Piola-Kirchhoff stress, P=F*S, for use in the momentum eq.
P = F * S_solid

# Momentum equation in solid:
f_s = Constant(d*(0,))         # body force in solid
f_s += -cd*v                   # to implement damping
res_s = rho_s0*inner(dv_ds - f_s,dv)*dX + inner(P,grad_X(dv))*dX

# %% [markdown]
# ## Fluid subproblem

# %%
# Shear rate helper function:
def gamma_dot(v):
    E_f = sym(grad_x(v))
    return sqrt(2.0*inner(E_f, E_f) + DOLFIN_EPS)

# Effective viscosity (Carreau model):
def mu_eff(v):
    return eta_f_inf + (eta_f_0 - eta_f_inf) \
           * (1.0 + (lam_r*gamma_dot(v))**2.0)**((n-1.0)/2.0)

# Cauchy stress of the fluid:
sigma_f = 2.0*mu_eff(v)*sym(grad_x(v)) - p*I

# Convective term of the fluid:
v_adv    = v - vhat
DvDt     = dv_dr + dot(grad_x(v),v_adv)
resGal_f = (rho_f*dot(DvDt,dv) + inner(sigma_f,grad_x(dv))
            + dp*div_x(v))*det_dxdy*dy(FLUID_FLAG)

# Stabilization:

# Deformed mesh size tensor in the spatial configuration:
J_m = Jacobian(mesh)                
dxi_dy = inv(J_m)
dxi_dx = dxi_dy*inv(grad_y(x))
G = (dxi_dx.T)*dxi_dx

# SUPG/PSPG:
resStrong_f = rho_f*DvDt - div_x_tens(sigma_f)
Cinv = Constant(1.0)
tau_M = 1.0/sqrt(((2*rho_f/Dt)**2) 
                 + inner(rho_f*v_adv,G*(rho_f*v_adv))
                 + Cinv*(eta_f_0**2)*inner(G,G))
resSUPG_f = inner(tau_M*resStrong_f,
                  rho_f*dot(grad_x(dv),v_adv)
                  + grad_x(dp))*det_dxdy*dy(FLUID_FLAG)
# LSIC/grad-div:
tau_C = 1.0/(tr(G)*tau_M + DOLFIN_EPS)
resLSIC_f = tau_C*div_x(v)*div_x(dv)*det_dxdy*dy(FLUID_FLAG)

# Stable Neumann BC term, assuming advective 
# form of material time derivative term and transforming
# normal and area element by Nanson's formula (on deforming mesh):
dsx_dsy_n_x = det_dxdy*inv(grad_y(x).T)*n_y
v_adv_minus = Min(dot(v_adv,dsx_dsy_n_x),Constant(0))
gm = Constant(1.0) # or 0.5
resOutflow_f = -gm*dot(rho_f*v_adv_minus*dv,v)*ds_y(OUTFLOW)
resInflow_f = -gm*dot(rho_f*v_adv_minus*dv,v)*ds_y(INFLOW)

# For inlet pressure BCs
if FLOW_OR_PRESSURE == "FLOW":
    Consistency_term = 0
elif FLOW_OR_PRESSURE == "PRESSURE":
    traction = -p_in*n_y
    Consistency_term = -(inner(det_dxdy*inv(grad_y(x).T)*traction,dv))*ds_y(INFLOW)
else:
    raise ValueError("FLOW_OR_PRESSURE must be either 'FLOW' or 'PRESSURE'")

# Total fluid residual:
res_f = resGal_f
# and stabilization terms as needed:
if SUPG:  
    res_f += resSUPG_f
if LSIC:
    res_f += resLSIC_f
if BACKFLOW_STAB:
    res_f += resOutflow_f
# Add consistent traction at inlet to enforce pressure as Neumann BC:
if FLOW_OR_PRESSURE == "PRESSURE":
    res_f += Consistency_term

# %% [markdown]
# ## Nonlinear solver(s) for the variational problems

# %%
# Nonlinear solver parameters; set relative tolerances
# for subproblems tighter than tolerance for coupled problem,
# to prevent stagnation.
REL_TOL_FSM   = 1e-4
ABS_TOL_FSM   = 1e-8
REL_TOL_FS    = REL_TOL_M = REL_TOL_FSM * 1e-1
ABS_TOL_FS    = ABS_TOL_M = ABS_TOL_FSM * 1e-1
MAX_ITERS_FSM = 100
MAX_ITERS_M   = 100
MAX_ITERS_FS  = 100
OMG_RELAX_FSM = 0.5

# MUMPS tuning for scaling/pivot robustness on ill-conditioned FSI Jacobians.
# PETScOptions.set() is global — applies to all PETSc solvers in the session.
PETScOptions.set('mat_mumps_icntl_8',  77)    # automatic scaling
PETScOptions.set('mat_mumps_icntl_24',  1)    # null pivot detection
PETScOptions.set('mat_mumps_icntl_13',  1)    # sequential ordering for stability
PETScOptions.set('mat_mumps_cntl_1',  0.001)  # small pivot threshold

# Use the PETSc SNES backend (instead of the built-in Newton) to get l2 line search.
def _configure_snes(solver, rel_tol, abs_tol, max_it):
    solver.parameters['nonlinear_solver'] = 'snes'  # top-level backend switch
    p = solver.parameters['snes_solver']
    p['linear_solver']           = 'mumps'
    p['line_search']             = 'l2'    # more robust than 'basic'
    p['relative_tolerance']      = rel_tol
    p['absolute_tolerance']      = abs_tol
    p['maximum_iterations']      = max_it
    p['error_on_nonconvergence'] = False   # let the time loop handle failures

# ---- Mesh motion problem ----
problem_m = NonlinearVariationalProblem(res_m, uhat, bcs_m, Dres_m)
solver_m  = NonlinearVariationalSolver(problem_m)
_configure_snes(solver_m, REL_TOL_M, ABS_TOL_M, MAX_ITERS_M)

# Residual of fluid--structure coupled problem:
res_fs  = res_f + res_s
Dres_fs = derivative(res_fs, w)

# ---- Fluid–structure problem ----
problem_fs = NonlinearVariationalProblem(res_fs, w, bcs_fs, Dres_fs)
solver_fs  = NonlinearVariationalSolver(problem_fs)
_configure_snes(solver_fs, REL_TOL_FS, ABS_TOL_FS, MAX_ITERS_FS)

# %% [markdown]
# # Time stepping

# %% [markdown]
# ## Initial conditions

# %%
# # Interpolate into subspaces
# V_sub = W.sub(0).collapse()
# Q_sub = W.sub(1).collapse()

# v_n_init = interpolate(v_rigid, V_sub)
# p_n_init = interpolate(p_rigid, Q_sub)

# # Assign to mixed function
# assign(w_old, [v_n_init, p_n_init])

# %% [markdown]
# ## Time stepping loop

# %%
# Create files for storing solution:
vfile = File(DataFolder+"velocity.pvd")
pfile = File(DataFolder+"pressure.pvd")
mfile = File(DataFolder+"mesh.pvd")

# Save initial condition to file:
# v_n_init.rename("v","v")
# p_n_init.rename("p","p")
# uhat.rename("u","u")
# vfile << v_n_init
# pfile << p_n_init
# mfile << uhat

# Prepare to store time-dependent post-processed quantities:
flow_rate_save = []
time_array = []

# Initialize time and step counter:
t = 0
count = 0

#while t <= FINAL_TIME:
for count in range(N_T_STEPS):     # more robust than t <= FINAL_TIME

    print(80*"=", flush=True)
    print(f"  Time step {count+1} of {N_T_STEPS}", 
          f"from t = {t:.3e} with Dt = {float(Dt):.3g}", flush=True)
    print(80*"=", flush=True)

    if FLOW_OR_PRESSURE == "FLOW":
        v_in.t = t
    elif FLOW_OR_PRESSURE == "PRESSURE":
        p_in.t = t
    else:
        raise ValueError("FLOW_OR_PRESSURE must be either 'FLOW' or 'PRESSURE'")

    # Reset Aitken parameters for each time step:
    r_prev = None
    OMG_RELAX_FSM = 0.5

    # Quasi-direct coupling loop:
    for i in range(0,MAX_ITERS_FSM):
        res_fs_vec = assemble(res_fs)
        for bc in bcs_fs:
            bc.apply(res_fs_vec,w.vector())
        res_norm = norm(res_fs_vec)
        if i == 0:
            res_norm0 = res_norm
        res_rel = res_norm/max(res_norm0, ABS_TOL_FSM)

        print(80*"*", flush=True)
        print(f"  Coupling iteration {i+1} ,",
              f"Absolute residual = {res_norm:.6e} ,",
              f"Relative residual = {res_rel:.6e}", flush=True)
        print(80*"*", flush=True)

        abs_ok = (res_norm < ABS_TOL_FSM)
        rel_ok = (res_rel < REL_TOL_FSM)
        if abs_ok or rel_ok:
            reason = "abs+rel" if (abs_ok and rel_ok) else ("abs" if abs_ok else "rel")
            print("  >>>>> Met", reason.upper(), "tolerance stopping criterion.", flush=True)
            break
        
        # Solve F-S problem:
        solver_fs.solve()
        u_proj = project(u,V)

        # Aitken's Δ² method: update omega dynamically
        r = u_proj.vector()[:] - u_func.vector()[:] 
        if r_prev is not None:
            dr = r - r_prev
            denom = np.dot(dr, dr)
            if denom > 1e-14 and denom > 1e-6 * np.dot(r, r):
                OMG_RELAX_FSM = -OMG_RELAX_FSM * np.dot(r_prev, dr) / denom
        r_prev = r.copy()
        # Now, apply relaxation:
        u_func.vector()[:] += OMG_RELAX_FSM * r

        # Run mesh update after relaxation:
        solver_m.solve()

    # Final mesh sync: enforce kinematic constraint exactly (no under-relaxation)
    # so that uhat_old at the next time step is consistent with the converged w.
    u_proj = project(u, V)
    u_func.assign(u_proj)
    solver_m.solve()

    # Post-process and advance time.
    (v, p) = w.split()

    if count % N_SKIP == 0:
        v.rename("v","v")
        p.rename("p","p")
        uhat.rename("u","u")
        vfile << v
        pfile << p
        mfile << uhat

    uhat_old.assign(uhat)
    w_old.assign(w)
    t += float(Dt)

    q_in_r = assemble(dot(v,n_y)*ds_y(INFLOW))
    q_in_d = assemble(dot(v,dsx_dsy_n_x)*ds_y(INFLOW))
    q_out_r = assemble(dot(v,n_y)*ds_y(OUTFLOW))
    q_out_d = assemble(dot(v,dsx_dsy_n_x)*ds_y(OUTFLOW))
    flow_rate_save.append([q_in_r,q_in_d,q_out_r,q_out_d])
    time_array.append(t)
# Out:
# ================================================================================
#   Time step 1 of 106 from t = 0.000e+00 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 0.000000e+00 , Relative residual = 0.000000e+00
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 0.000000000000e+00
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 2 of 106 from t = 3.562e-03 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438004e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587039673656e+04
#   1 SNES Function norm 7.473524220362e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 5.838777148371e-04
#   1 SNES Function norm 4.172129203404e-08
#   2 SNES Function norm 5.743504294239e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 7.861224e-02 , Relative residual = 9.316450e-06
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 5.838119441042e-04
#   1 SNES Function norm 4.163452144440e-08
#   2 SNES Function norm 5.703423014410e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 3 of 106 from t = 7.124e-03 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438108e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587043069741e+04
#   1 SNES Function norm 6.681633120349e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 6.349131537066e-04
#   1 SNES Function norm 3.247602151967e-08
#   2 SNES Function norm 3.753938072449e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 9.054920e-02 , Relative residual = 1.073098e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 6.348365820645e-04
#   1 SNES Function norm 3.241621886173e-08
#   2 SNES Function norm 3.741587359472e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 4 of 106 from t = 1.069e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438125e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587043613951e+04
#   1 SNES Function norm 4.398084054413e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 6.580286736342e-04
#   1 SNES Function norm 2.754677590490e-08
#   2 SNES Function norm 2.926595322257e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 8.585664e-02 , Relative residual = 1.017485e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 6.579409871276e-04
#   1 SNES Function norm 2.749911658589e-08
#   2 SNES Function norm 2.918953721831e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 5 of 106 from t = 1.425e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438138e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587044031972e+04
#   1 SNES Function norm 2.943435473447e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 6.810652181909e-04
#   1 SNES Function norm 2.507843176884e-08
#   2 SNES Function norm 2.579462343289e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 9.422692e-02 , Relative residual = 1.116679e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 6.809681292215e-04
#   1 SNES Function norm 2.503610044739e-08
#   2 SNES Function norm 2.573143052103e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 6 of 106 from t = 1.781e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438153e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587044527397e+04
#   1 SNES Function norm 2.314984388649e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.022369723479e-04
#   1 SNES Function norm 2.361356523247e-08
#   2 SNES Function norm 2.375867609667e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 1.094356e-01 , Relative residual = 1.296914e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.021323629555e-04
#   1 SNES Function norm 2.357519433162e-08
#   2 SNES Function norm 2.370423176335e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 7 of 106 from t = 2.137e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438168e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587045005406e+04
#   1 SNES Function norm 2.074878754540e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.210447978286e-04
#   1 SNES Function norm 2.265200834841e-08
#   2 SNES Function norm 2.237522428721e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 1.265945e-01 , Relative residual = 1.500261e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.209341961917e-04
#   1 SNES Function norm 2.261709263600e-08
#   2 SNES Function norm 2.232580708470e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 8 of 106 from t = 2.493e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438181e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587045426777e+04
#   1 SNES Function norm 1.982341861657e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.375253913023e-04
#   1 SNES Function norm 2.197952949957e-08
#   2 SNES Function norm 2.135901340331e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 1.443873e-01 , Relative residual = 1.711119e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.374100212621e-04
#   1 SNES Function norm 2.194776507615e-08
#   2 SNES Function norm 2.131444710746e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 9 of 106 from t = 2.850e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438192e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587045788282e+04
#   1 SNES Function norm 1.947073781838e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 7.518235881938e-04
#   1 SNES Function norm 2.148915394845e-08
#   2 SNES Function norm 2.057388559440e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 1.624593e-01 , Relative residual = 1.925285e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.517044471117e-04
#   1 SNES Function norm 2.146031557279e-08
#   2 SNES Function norm 2.053121431168e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 10 of 106 from t = 3.206e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438201e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587046097179e+04
#   1 SNES Function norm 1.936830812035e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.641259281117e-04
#   1 SNES Function norm 2.112201070763e-08
#   2 SNES Function norm 1.994408863995e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 1.806965e-01 , Relative residual = 2.141411e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.640038425089e-04
#   1 SNES Function norm 2.109591600133e-08
#   2 SNES Function norm 1.990506218521e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 11 of 106 from t = 3.562e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438209e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587046361834e+04
#   1 SNES Function norm 1.939305453014e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 7.746378873601e-04
#   1 SNES Function norm 2.084292361302e-08
#   2 SNES Function norm 1.942791431188e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 1.990557e-01 , Relative residual = 2.358980e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.745135496969e-04
#   1 SNES Function norm 2.081941842931e-08
#   2 SNES Function norm 1.938934347922e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 12 of 106 from t = 3.918e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438216e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587046589418e+04
#   1 SNES Function norm 1.949123401751e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.835685144859e-04
#   1 SNES Function norm 2.062934612405e-08
#   2 SNES Function norm 1.899366836287e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 2.175173e-01 , Relative residual = 2.577764e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.834425078718e-04
#   1 SNES Function norm 2.060829677457e-08
#   2 SNES Function norm 1.895783038181e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 13 of 106 from t = 4.274e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438222e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587046785743e+04
#   1 SNES Function norm 1.963521384522e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 7.911199109536e-04
#   1 SNES Function norm 2.046598287777e-08
#   2 SNES Function norm 1.862265346867e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 2.360709e-01 , Relative residual = 2.797638e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.909927267932e-04
#   1 SNES Function norm 2.044727118083e-08
#   2 SNES Function norm 1.858921437716e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 14 of 106 from t = 4.631e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438228e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587046955558e+04
#   1 SNES Function norm 1.980865395740e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.974805850504e-04
#   1 SNES Function norm 2.034198925412e-08
#   2 SNES Function norm 1.830137969008e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 2.547098e-01 , Relative residual = 3.018522e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 7.973526366239e-04
#   1 SNES Function norm 2.032550913390e-08
#   2 SNES Function norm 1.826887699692e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 15 of 106 from t = 4.987e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438232e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047102823e+04
#   1 SNES Function norm 2.000106089640e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.028217920811e-04
#   1 SNES Function norm 2.024941373872e-08
#   2 SNES Function norm 1.801822743302e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 2.734288e-01 , Relative residual = 3.240356e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.026934256871e-04
#   1 SNES Function norm 2.023506875505e-08
#   2 SNES Function norm 1.798670832491e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 16 of 106 from t = 5.343e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438236e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587047230907e+04
#   1 SNES Function norm 2.020549696937e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.072960465828e-04
#   1 SNES Function norm 2.018227602093e-08
#   2 SNES Function norm 1.776665184427e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 2.922233e-01 , Relative residual = 3.463086e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.071675510669e-04
#   1 SNES Function norm 2.016997751476e-08
#   2 SNES Function norm 1.773481516524e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 17 of 106 from t = 5.699e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438240e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047342702e+04
#   1 SNES Function norm 2.041740639134e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 8.110371089989e-04
#   1 SNES Function norm 2.013598962611e-08
#   2 SNES Function norm 1.753843379307e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 3.110894e-01 , Relative residual = 3.686662e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.109087240717e-04
#   1 SNES Function norm 2.012565530606e-08
#   2 SNES Function norm 1.750789500479e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 18 of 106 from t = 6.056e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438243e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047440706e+04
#   1 SNES Function norm 2.063388891549e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 8.141608977111e-04
#   1 SNES Function norm 2.010698222804e-08
#   2 SNES Function norm 1.733067989940e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 3.300231e-01 , Relative residual = 3.911040e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.140328212520e-04
#   1 SNES Function norm 2.009853506488e-08
#   2 SNES Function norm 1.730093914155e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 19 of 106 from t = 6.412e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438245e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047527071e+04
#   1 SNES Function norm 2.085319623064e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 8.167669237332e-04
#   1 SNES Function norm 2.009243573188e-08
#   2 SNES Function norm 1.713818357565e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 3.490208e-01 , Relative residual = 4.136178e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.166393181908e-04
#   1 SNES Function norm 2.008580310558e-08
#   2 SNES Function norm 1.710912512575e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 20 of 106 from t = 6.768e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438248e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047603649e+04
#   1 SNES Function norm 2.107436775667e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.********************************************************************************
#
#   0 SNES Function norm 8.189399692767e-04
#   1 SNES Function norm 2.009010263118e-08
#   2 SNES Function norm 1.695887776708e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 3.680793e-01 , Relative residual = 4.362035e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.188129672426e-04
#   1 SNES Function norm 2.008521564482e-08
#   2 SNES Function norm 1.692874666048e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 21 of 106 from t = 7.124e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438250e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047672026e+04
#   1 SNES Function norm 2.129696661764e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# ********************************************************************************Solving nonlinear variational problem.
#
#   0 SNES Function norm 8.207518271180e-04
#   1 SNES Function norm 2.009817299316e-08
#   2 SNES Function norm 1.678862933139e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 3.871955e-01 , Relative residual = 4.588576e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.206255361455e-04
#   1 SNES Function norm 2.009496593924e-08
#   2 SNES Function norm 1.675976267179e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 22 of 106 from t = 7.480e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438252e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047733555e+04
#   1 SNES Function norm 2.152089105907e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.222629873788e-04
#   1 SNES Function norm 2.011517627183e-08
#   2 SNES Function norm 1.662725750410e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 4.063669e-01 , Relative residual = 4.815772e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.221374941163e-04
#   1 SNES Function norm 2.011358621819e-08
#   2 SNES Function norm 1.659919109526e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 23 of 106 from t = 7.837e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438253e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047789384e+04
#   1 SNES Function norm 2.174624267479e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.235242068891e-04
#   1 SNES Function norm 2.013990769570e-08
#   2 SNES Function norm 1.647245221668e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 4.255912e-01 , Relative residual = 5.043594e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.233995806014e-04
#   1 SNES Function norm 2.013987415231e-08
#   2 SNES Function norm 1.644361364803e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 24 of 106 from t = 8.193e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438255e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047840485e+04
#   1 SNES Function norm 2.197323667271e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.245779288802e-04
#   1 SNES Function norm 2.017137240105e-08
#   2 SNES Function norm 1.632252090197e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 4.448665e-01 , Relative residual = 5.272020e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.244542244284e-04
#   1 SNES Function norm 2.017283706941e-08
#   2 SNES Function norm 1.629473085134e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 25 of 106 from t = 8.549e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438256e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047887677e+04
#   1 SNES Function norm 2.220214258910e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.254595418116e-04
#   1 SNES Function norm 2.020874258301e-08
#   2 SNES Function norm 1.617633362711e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 4.641912e-01 , Relative residual = 5.501032e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.253368021608e-04
#   1 SNES Function norm 2.021164915144e-08
#   2 SNES Function norm 1.614904810272e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 26 of 106 from t = 8.905e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438258e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587047931648e+04
#   1 SNES Function norm 2.243324655299e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.261984791284e-04
#   1 SNES Function norm 2.025132431915e-08
#   2 SNES Function norm 1.603479440831e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 4.835642e-01 , Relative residual = 5.730617e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.260767374481e-04
#   1 SNES Function norm 2.025561831795e-08
#   2 SNES Function norm 1.600714543727e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 27 of 106 from t = 9.261e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438259e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587047972975e+04
#   1 SNES Function norm 2.266682848464e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 8.268191692716e-04
#   1 SNES Function norm 2.029853170655e-08
#   2 SNES Function norm 1.589409014576e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 5.029847e-01 , Relative residual = 5.960764e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# ================================================================================Solving nonlinear variational problem.
#
#   0 SNES Function norm 8.266984506872e-04
#   1 SNES Function norm 2.030416038585e-08
#   2 SNES Function norm 1.586784397405e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 28 of 106 from t = 9.618e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438260e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.587048012141e+04
#   1 SNES Function norm 2.290314938606e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.273418491675e-04
#   1 SNES Function norm 2.034986652786e-08
#   2 SNES Function norm 1.575610205305e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 5.224521e-01 , Relative residual = 6.191467e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.272221722153e-04
#   1 SNES Function norm 2.035677876420e-08
#   2 SNES Function norm 1.572879993720e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 29 of 106 from t = 9.974e-02 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438261e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587048049549e+04
#   1 SNES Function norm 2.314244529756e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.277832560012e-04
#   1 SNES Function norm 2.040490217894e-08
#   2 SNES Function norm 1.561976300401e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 5.419663e-01 , Relative residual = 6.422724e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.276646338338e-04
#   1 SNES Function norm 2.041304840947e-08
#   2 SNES Function norm 1.559265362943e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 30 of 106 from t = 1.033e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438262e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587048085536e+04
#   1 SNES Function norm 2.338492550729e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.281572122194e-04
#   1 SNES Function norm 2.046327089949e-08
#   2 SNES Function norm 1.548377773330e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 5.615273e-01 , Relative residual = 6.654537e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.280396536015e-04
#   1 SNES Function norm 2.047260306382e-08
#   2 SNES Function norm 1.545838793863e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 31 of 106 from t = 1.069e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438264e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587048120384e+04
#   1 SNES Function norm 2.363077338225e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 8.284751180088e-04
#   1 SNES Function norm 2.052465357349e-08
#   2 SNES Function norm 1.534879651690e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 5.811356e-01 , Relative residual = 6.886909e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.283586281374e-04
#   1 SNES Function norm 2.053512506727e-08
#   2 SNES Function norm 1.532450203850e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 32 of 106 from t = 1.104e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438265e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.587048154325e+04
#   1 SNES Function norm 2.388014869908e-02
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_RELATIVE.
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.287463643411e-04
#   1 SNES Function norm 2.058877153965e-08
#   2 SNES Function norm 1.521592345604e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 6.007916e-01 , Relative residual = 7.119848e-05
# ********************************************************************************
#   >>>>> Met REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 8.286309455202e-04
#   1 SNES Function norm 2.060033718123e-08
#   2 SNES Function norm 1.519096803799e-14
#   PETSc SNES solver converged in 2 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 33 of 106 from t = 1.140e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.438266e+03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
# ...
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.901772556579e-06
#   1 SNES Function norm 2.143955217853e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 1.563678173628e-09
#   1 SNES Function norm 1.655877983114e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 5 , Absolute residual = 1.721953e-06 , Relative residual = 1.349262e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.721953474938e-06
#   1 SNES Function norm 2.151648625591e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.964747770041e-10
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 6 , Absolute residual = 2.151650e-11 , Relative residual = 1.685957e-08
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# ================================================================================Solving nonlinear variational problem.
#   0 SNES Function norm 1.592949554248e-09
#
#   1 SNES Function norm 1.618319144721e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 103 of 106 from t = 3.633e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 1.014687e-03 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.014687082042e-03
#   1 SNES Function norm 2.458752701544e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 9.509106526280e-09
#   1 SNES Function norm 1.617767674117e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 2 , Absolute residual = 9.326084e-06 , Relative residual = 9.191093e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 9.326083592486e-06
#   1 SNES Function norm 2.196038968757e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************Solving nonlinear variational problem.
#
#   0 SNES Function norm 4.821573017528e-09
#   1 SNES Function norm 1.499581700808e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 3 , Absolute residual = 4.125006e-06 , Relative residual = 4.065299e-03
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 4.125006411891e-06
#   1 SNES Function norm 2.145327619542e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.448344843523e-09
#   1 SNES Function norm 1.567469417476e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 4 , Absolute residual = 2.333781e-06 , Relative residual = 2.300000e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.333780746798e-06
#   1 SNES Function norm 2.183889582289e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 1.245073925093e-09
#   1 SNES Function norm 1.650825238762e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 5 , Absolute residual = 1.386890e-06 , Relative residual = 1.366815e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.386889722445e-06
#   1 SNES Function norm 2.121411456212e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 6.342724706247e-10
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 6 , Absolute residual = 2.121410e-11 , Relative residual = 2.090704e-08
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# Solving nonlinear variational problem.================================================================================
#
#   0 SNES Function norm 1.268544940782e-09
#   1 SNES Function norm 1.639800541429e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 104 of 106 from t = 3.669e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 8.077666e-04 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 8.077666291015e-04
#   1 SNES Function norm 2.239004415433e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 7.566044436773e-09
#   1 SNES Function norm 1.710811508346e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 7.434535e-06 , Relative residual = 9.203815e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.434534902776e-06
#   1 SNES Function norm 2.079374204891e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 3.836360055500e-09
#   1 SNES Function norm 1.621389967655e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 3 , Absolute residual = 3.288467e-06 , Relative residual = 4.071060e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 3.288466783439e-06
#   1 SNES Function norm 2.167729751835e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.948073807134e-09
#   1 SNES Function norm 1.519500629838e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 4 , Absolute residual = 1.861158e-06 , Relative residual = 2.304079e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.861157732773e-06
#   1 SNES Function norm 2.174265263341e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************Solving nonlinear variational problem.
#
#   0 SNES Function norm 9.906747974902e-10
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 5 , Absolute residual = 2.174265e-11 , Relative residual = 2.691700e-08
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# Solving nonlinear variational problem.
# ================================================================================
#   0 SNES Function norm 1.981349595314e-09
#   1 SNES Function norm 1.555936823487e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Time step 105 of 106 from t = 3.705e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 6.421342e-04 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 6.421342482393e-04
#   1 SNES Function norm 2.199367271800e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 6.026019907989e-09
#   1 SNES Function norm 1.603612522528e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 5.932642e-06 , Relative residual = 9.238944e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 5.932642233585e-06
#   1 SNES Function norm 2.190987776665e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 3.055864701371e-09
#   1 SNES Function norm 1.654354711463e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 3 , Absolute residual = 2.652109e-06 , Relative residual = 4.130147e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.652108801732e-06
#   1 SNES Function norm 2.116255357619e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 1.551962819192e-09
#   1 SNES Function norm 1.632101759595e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 4 , Absolute residual = 1.507754e-06 , Relative residual = 2.348036e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.507754137326e-06
#   1 SNES Function norm 2.119443688111e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 7.893741046157e-10
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
#   Coupling iteration 5 , Absolute residual = 2.119448e-11 , Relative residual = 3.300630e-08
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.578748208988e-09
#   1 SNES Function norm 1.671907636211e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ================================================================================
#   Time step 106 of 106 from t = 3.740e-01 with Dt = 0.00356
# ================================================================================
# ********************************************************************************
#   Coupling iteration 1 , Absolute residual = 5.114194e-04 , Relative residual = 1.000000e+00
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 5.114193604492e-04
#   1 SNES Function norm 2.166804506716e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 4.794951228959e-09
#   1 SNES Function norm 1.607449005557e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 2 , Absolute residual = 4.735587e-06 , Relative residual = 9.259695e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 4.735587285574e-06
#   1 SNES Function norm 2.166614712552e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 2.431590752317e-09
#   1 SNES Function norm 1.728251237472e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 3 , Absolute residual = 2.117733e-06 , Relative residual = 4.140893e-03
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 2.117733100764e-06
#   1 SNES Function norm 2.179364359374e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# ********************************************************************************
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.234928184474e-09
#   1 SNES Function norm 1.656486540526e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 4 , Absolute residual = 1.204778e-06 , Relative residual = 2.355754e-03
# ********************************************************************************
# Solving nonlinear variational problem.
# ********************************************************************************
#   0 SNES Function norm 1.204778054315e-06
#   1 SNES Function norm 2.136629895743e-11
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.
# Solving nonlinear variational problem.
#   0 SNES Function norm 6.281293284881e-10
#   PETSc SNES solver converged in 0 iterations with convergence reason CONVERGED_FNORM_ABS.
#   Coupling iteration 5 , Absolute residual = 2.136632e-11 , Relative residual = 4.177847e-08
# ********************************************************************************
#   >>>>> Met ABS+REL tolerance stopping criterion.
# Solving nonlinear variational problem.
#   0 SNES Function norm 1.256258656898e-09
#   1 SNES Function norm 1.623965025717e-17
#   PETSc SNES solver converged in 1 iterations with convergence reason CONVERGED_FNORM_ABS.

# %% [markdown]
# # Visualization and post-processing

# %% [markdown]
# Some meshing preliminaries.
#
# We make horizontal scales dimensionless by dividing by $\ell$, and vertical scales dimensionless by dividing by $h_0+b_0$.

# %%
# Extract coordinates and displacement values:
coordinates = mesh.coordinates()
cells = mesh.cells()
dim = mesh.geometry().dim()
num_vertices = len(coordinates)

# Create triangulation and plot:
x_coords = coordinates[:, 0]/l
y_coords = coordinates[:, 1]/(h0+b0)
triang = tri.Triangulation(x_coords, y_coords, cells)

# Get displacement components by projecting algebraic u onto V space:
u_fn = project(u, V)
ux, uy = u_fn.split(deepcopy=True)

# %% [markdown]
# ## Diagnostics

# %%
time_array = np.array(time_array)
saved_qs = np.array(flow_rate_save)

# %%
# Mesh Jacobian checks:
J_mesh = project(det(grad_y(y+u)), FunctionSpace(mesh, "DG", 0))
J_vals = J_mesh.vector()[:]

# Some div v diagnostics:
mass_residual = assemble(det_dxdy * div_x(v) * dx(FLUID_FLAG))

V0 = FunctionSpace(mesh, "DG", 0)
divv = project(div_x(v), V0)

# Pressure diagnostics:
x_test = np.array([0.0, l/3, l/2, 2*l/3, l])
p_computed = [p(xi, h0/2) for xi in x_test]
p_theory = [p_sh(xi, h0/2) for xi in x_test]

print("======================== DIAGNOSTICS ========================")
print(f"det(F) min: {J_vals.min():.6f}            |  "
      f"det(F) max: {J_vals.max():.6f}")
print(f"Number of inverted elements: {sum(J_vals < 0)}  |  "
      f"Number near-inverted (J < 0.3): {sum(J_vals < 0.3)}")

# Where is the problem?
if J_vals.min() < 0.3:
    bad_cells = np.where(J_vals < 0.3)[0]
    print(f"Problematic cells: {bad_cells[:10]}")  # First 10

    # Get coordinates of bad cells
    V0 = FunctionSpace(mesh, "DG", 0)
    coords = V0.tabulate_dof_coordinates()
    for cell_id in bad_cells[:5]:
        print(
            f"  Cell {cell_id} at ({coords[cell_id, 0]:.4f}, {coords[cell_id, 1]:.4f})")

print()
print(f"Q_in    = {q_rigid:.12e}   (rigid)")
print(f"Q_in    = {float(q_sh):.12e}   (soft hydraulic theory)")
print(f"Q_in    = {saved_qs[-1,1]:.12e}  (sim, expect < 0),  ",
      f"% err={100.0*abs(-saved_qs[-1,1]-float(q_sh))/abs(float(q_sh)):.2f}%")
print(f"Q_out   = {saved_qs[-1,3]:.12e}   (sim, expect > 0),  ",
      f"% err={100.0*abs(saved_qs[-1,3]-float(q_sh))/abs(float(q_sh)):.2f}%")

print()
print(f"Q_in + Q_out : {saved_qs[-1,1] + saved_qs[-1,3]:.6e} (target: < 1e-6 ?)")
print(f"∫ div(v) dΩ  : {mass_residual:.6e} (target: < 1e-8 ?)")


# Interpolate the inlet profile to the velocity space restricted on the inflow
v_in_V = interpolate(v_in, W.sub(0).collapse())

# Compute L2 mismatch *on the inflow boundary* (via boundary integral of full vector)
if FLOW_OR_PRESSURE == "FLOW":
    mismatch_vec = assemble(inner(v - v_in_V, v - v_in_V) * ds(INFLOW))
    print()
    print("inlet velocity profile mismatch (only small if imposing v BC)")
    print(f"||v - v_in||_L2(Γ_in) = {mismatch_vec**0.5:.6e}")

print()
print(f"p_inlet  = {p_rigid(0, h0):.4f} Pa (rigid)")
print(f"p_inlet  = {p_theory[0]:.4f} Pa (soft hydraulics (plaw))")
print(f"p_inlet  = {p_computed[0]:.4f} Pa (sim)")
print()
print("Pressure (p/p_c) comparisons at interface y=h_0:")
for label, i in [("x=0", 0), ("x=l/3", 1), ("x=l/2", 2), ("x=2l/3", 3)]:
    s, t = p_computed[i], p_theory[i]
    err = 100.0 * abs(s - t) / abs(t) if abs(t) > 1e-30 else float('nan')
    print(f"  {label:6s}: sim = {s/float(p_c):8.6f}, "
          f"soft hydraulics (plaw) = {t/float(p_c):8.6f}, % err={err:.2f}%")
print("=============================================================")
# Out:
# ======================== DIAGNOSTICS ========================
# det(F) min: 0.894840            |  det(F) max: 1.577418
# Number of inverted elements: 0  |  Number near-inverted (J < 0.3): 0
#
# Q_in    = 3.333333333333e-03   (rigid)
# Q_in    = 3.898652201352e-03   (soft hydraulic theory)
# Q_in    = -3.843479804003e-03  (sim, expect < 0),   % err=1.42%
# Q_out   = 3.851872821347e-03   (sim, expect > 0),   % err=1.20%
#
# Q_in + Q_out : 8.393017e-06 (target: < 1e-6 ?)
# ∫ div(v) dΩ  : 1.529029e-05 (target: < 1e-8 ?)
#
# p_inlet  = 200000.0000 Pa (rigid)
# p_inlet  = 200000.0000 Pa (soft hydraulics (plaw))
# p_inlet  = 200000.0000 Pa (sim)
#
# Pressure (p/p_c) comparisons at interface y=h_0:
#   x=0   : sim = 1.000000, soft hydraulics (plaw) = 1.000000, % err=0.00%
#   x=l/3 : sim = 0.698785, soft hydraulics (plaw) = 0.698656, % err=0.02%
#   x=l/2 : sim = 0.537416, soft hydraulics (plaw) = 0.537370, % err=0.01%
#   x=2l/3: sim = 0.367493, soft hydraulics (plaw) = 0.367897, % err=0.11%
# =============================================================

# %% [markdown]
# ## Inlet/outlet flow rates

# %%
# Create plot:
fig, ax = plt.subplots()
ax.plot(time_array, float(q_rigid/q_c)*np.ones(len(time_array)), 
        label='rigid theory', linestyle='dashed', color='black')

# Note: signed flow rate is negative at inlet and positive at outlet
# ax.plot(time_array, -saved_qs[:,0]/float(q_c), 
#         label=r'ALE-FSI, initial/rigid inlet', color='blue')
ax.plot(time_array, -saved_qs[:,1]/float(q_c), 
        label=r"ALE-FSI, inlet (Nanson)")
# ax.plot(time_array, saved_qs[:,2]/float(q_c), 
#         label=r'ALE-FSI, initial/rigid outlet', color='cornflowerblue')
ax.plot(time_array, saved_qs[:,3]/float(q_c), 
        label=r"ALE-FSI, outlet (Nanson)")

ax.plot(time_array, float(q_sh/q_c)*np.ones(len(time_array)), 
        label='soft hydraulics (plaw)', linestyle='dotted', color='red')

ax.set_xlabel('$t$')
ax.set_ylabel('$q/q_c$')
ax.grid(alpha=0.5, linestyle='dotted')

ax.legend()

ax.set_xlim(0, np.round(time_array[-1],2))
#ax.set_ylim(0, float(q_amp))
#ax.set_aspect(1)
ax.set_box_aspect(1 / 2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Height-averaged axial pressure distribution

# %%
# Sampling parameters:
num_x_samples = 50
num_y_samples = 100
x_vals = np.linspace(0.0, l, num_x_samples)
y_line = np.linspace(0.0, h0, num_y_samples)

# Cross-sectional averages via line integrals (trapz along y at fixed x).
# More accurate than strip-indicator approach: no area-averaging artefacts,
# no DG0/CG1 indicator mismatch, proper 1/h0 normalisation.

# Sampling d, dp/dx, d2p/dx2:
avg_p = np.array([
    trapz([p(float(xi), float(yj)) for yj in y_line], y_line) / h0
    for xi in x_vals
])

# If needed, d/dx and d2/dx2 axial derivatives 
# via central differences (O(Δx²) interior):
# avg_dpdx   = np.gradient(avg_p,    x_vals)
# avg_d2pdx2 = np.gradient(avg_dpdx, x_vals)

# Rigid-channel and soft-hydraulic reference pressures:
pressure_rigid = np.array([p_rigid(float(xi), 0.0) for xi in x_vals])
pressure_sh    = np.array([p_sh(float(xi),    0.0) for xi in x_vals])

# %%
# Create plot:
fig, ax = plt.subplots(tight_layout=True)
ax.plot(x_vals/l, pressure_rigid/float(p_c), 
        label='rigid theory', linestyle='dashed', color='black')
ax.plot(x_vals/l, avg_p/float(p_c), 
        label='ALE-FSI, $y$-averaged', color='blue')
ax.plot(x_vals/l, pressure_sh/float(p_c), 
        label='soft hydraulics (plaw)', linestyle='dotted', color='red')

ax.set_xlabel(r'$z/\ell$')
ax.set_ylabel('$p/p_c$')
ax.grid(alpha=0.5, linestyle='dotted')

ax.legend()

ax.set_xlim(0, 1)
#ax.set_ylim(0, pressure_rigid[0]/float(p_c))
#ax.set_yticks(np.arange(0,pressure_rigid[0]/float(p_c)+0.1,2))
#ax.set_aspect(1)
ax.set_box_aspect(1 / 2)

print(f"Reminder: compliance #, α = {alpha:.5f}")

plt.show()
# Out:
# Reminder: compliance #, α = 0.10545

# %% [markdown]
# ## Fluid&ndash;solid interface displacement and pressure

# %%
# Create points along the fluid-solid interface:
fs_line_points = [(x, h0) for x in x_vals]

# Evaluate the vertical displacement and pressure at each point:
uy_fs_values = np.array([uy(point) for point in fs_line_points])
ux_fs_values = np.array([ux(point) for point in fs_line_points])
p_fs_values  = np.array([p(point) for point in fs_line_points])
# d/dx and d2/dx2 axial derivatives via central differences, O(Δx²):
dpdx_fs      = np.gradient(p_fs_values, x_vals)
d2pdx2_fs    = np.gradient(dpdx_fs, x_vals)

# Create plot:
fig, ax = plt.subplots(tight_layout=True)
ax.plot(x_vals/l, uy_fs_values/float(alpha*h0),
        label=r'$u_y/(\alpha h_0)$', color='orange')
ax.plot(x_vals/l, p_fs_values/float(p_c), 
        label='$p/p_c$', color='red', linestyle='dotted')
ax.plot(x_vals/l, ux_fs_values/float(alpha*h0),
        label=r'$u_x/(\alpha h_0)$', color='springgreen')
ax.plot(x_vals/l, -vartheta*dpdx_fs/(float(p_c)/l), 
        label=r'$d(p/p_c)/d(z/\ell)$', color='green', linestyle='dotted')

ax.set_xlabel(r'$z/\ell$')
#ax.set_ylabel()
ax.grid(alpha=0.5, linestyle='dotted')

ax.legend(title="At FS interface:", title_fontsize='large')

ax.set_xlim(0, 1)
#ax.set_ylim(0, pressure_rigid[0]/float(p_c))
#ax.set_yticks(np.arange(0,pressure_rigid[0]/float(p_c)+0.1,2))
#ax.set_aspect(1)
ax.set_box_aspect(1 / 2)

print(f"Reminder: compliance #, α = {alpha:.5f}")

plt.show()
# Out:
# Reminder: compliance #, α = 0.10545

# %% [markdown]
# ## Pressure contours

# %%
# Get pressure values at vertices:
pressure_values = p.compute_vertex_values(mesh)

# Create plot:
fig, ax = plt.subplots(tight_layout=True)
contour = ax.tricontourf(triang, pressure_values/float(p_c), 
                         levels=20, cmap='pink_r')
fig.colorbar(contour, label='$p/p_c$', orientation='horizontal')

ax.set_xlabel(r'$z/\ell$')
ax.set_ylabel(r'$y/(h_0+b_0)$')

ax.set_aspect(1 / 4)

plt.show()

# %% [markdown]
# ## Fluid velocity magnitude contours

# %%
# Get velocity values at vertices:
vx, vy = v.split()
vx_values = vx.compute_vertex_values(mesh)
vy_values = vy.compute_vertex_values(mesh)

# Compute magnitude:
magnitude = np.sqrt(vx_values**2 + vy_values**2)

# Create plot:
fig, ax = plt.subplots()
contour = ax.tricontourf(triang, magnitude/float(v_c), 
                         levels=20, cmap='Blues')
cb = fig.colorbar(contour, orientation='horizontal')
if params['text.usetex']:
    cb.set_label(r'$|\bm{v}|/v_c$')
else:
    cb.set_label(r'$|\vec{v}|/v_c$')

ax.set_xlabel(r'$z/\ell$')
ax.set_ylabel(r'$y/(h_0+b_0)$')

ax.set_aspect(1 / 4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Displacement magnitude contours

# %% [markdown]
# We will mask all $y/h_0 < h_0/(h_0+b_0)$ to show only the displacement fiend in the solid. There is mesh displacement in the fluid domain but we do not consider that to be "physical."

# %%
# Get displacement values at vertices:
ux_values = ux.compute_vertex_values(mesh)
uy_values = uy.compute_vertex_values(mesh)

# Compute magnitude:
magnitude = np.sqrt(ux_values**2 + uy_values**2)
# Mask off fluid domain, need to deep copy the triang:
masked_triang =  tri.Triangulation(x_coords.copy(), 
                                   y_coords.copy(), 
                                   cells.copy())
masked_triang.set_mask(
    np.mean(y_coords[masked_triang.triangles], axis=1) < h0/(h0+b0))

# Create plot:
fig, ax = plt.subplots(tight_layout=True)
contour = ax.tricontourf(masked_triang, magnitude/float(alpha*h0), 
                         levels=20, cmap='hot_r')

cb = fig.colorbar(contour, orientation='horizontal')
if params['text.usetex']:
    cb.set_label(r'$|\bm{u}|/u_c$')
else:
    cb.set_label(r'$|\vec{u}|/u_c$')

ax.set_xlabel(r'$z/\ell$')
ax.set_ylabel(r'$y/(h_0+b_0)$')

ax.set_aspect(1 / 4)

plt.show()
